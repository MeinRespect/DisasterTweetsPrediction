# %%
import pandas as pd
import numpy as np
import re

from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer, BertModel
from torch.optim.lr_scheduler import ExponentialLR
from torch import nn
import torch

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from flashtext import KeywordProcessor
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import codecs
import spacy

from sklearn.metrics import f1_score
from sklearn import preprocessing

from niacin.augment import RandAugment
from niacin.text import en

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')

stop_words = stopwords.words('english')

device = torch.device('cuda:3')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /cephfs/projects/vagishev/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /cephfs/projects/vagishev/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /cephfs/projects/vagishev/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from comet_ml import Experiment

experiment = Experiment(
    api_key="aoUalWmaagcfhfpRszq9USwVb",
    project_name="twitter-threat-classification",
    workspace="zanzibara1961",
    log_code=True
)

# %%
df = pd.read_csv('train.csv', index_col = 'id').reset_index(drop=True)
df

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.loc[df['keyword'].isnull(), 'keyword'] = 'Null'

# %%
df.keyword = df.keyword.str.replace('%20', '')

stemmer = PorterStemmer()

df.keyword = df.keyword.apply(lambda x: stemmer.stem(x))

# %%
df = df.sample(frac = 1).reset_index(drop=True)

# %%
dumm_columns = pd.get_dummies(df['keyword']).columns
len(dumm_columns)

# %%
sum_1 = 0
for i in df['text'].str.lower().str.split():
    sum_1 += len(i)
sum_1 / len(df)

# %%
class TweetsDataset(Dataset):
    
    """Dataset for creating a dataset of text.

    Parameters:
    data (pd.DataFrame): Data for the dataset.
    target (list): Target values.
    include_keyword (bool, optional): Whether to include keyword in the dataset. Defaults to True.
    max_len (int, optional): Maximum length of the sequence. Defaults to 15.
    dumm_column (str, optional): Column to use for creating dummy variables. Defaults to None.
    lemmatize (bool, optional): Whether to lemmatize the text. Defaults to True.
    prepear (bool, optional): Whether to preprocess the text. Defaults to True.
    """
    
    def __init__(self, data, target, include_keyword = True, max_len = 15, 
                 dumm_column=None, lemmatize=True, prepear = True):
        
        super().__init__()
        self.dataset         = data
        self.target          = target
        self.include_keyword = include_keyword
        self.len             = len(data)
        self.lemmatize       = lemmatize
        self.prepear         = prepear
        self.lemmatizer      = WordNetLemmatizer() 
        self.max_len         = max_len
        
        if self.include_keyword:
            self.keywords = self.get_dummies_(self.dataset, dumm_columns)
     
        self.replacements    = ('UTC', ']', '.', '[', '?', '!', "'", ':', '=>', '-', 
                                '//t', '/', '&', ';', 'å', '`',
                                'ê', '+', '=', '(', ')', '|', '*', '_', 
                                '%', '$', '>', '<', 'ì', '¼', '~', 'http', '#', '@', '\n')
        
    def get_dummies_(self, dataset, dumm_columns):

        dummies = pd.DataFrame(0, index=np.arange(len(dataset)), columns=dumm_columns)
        for index in range(len(dataset)):
            
            if X_train.loc[index, 'keyword'] in dumm_columns:
                column = np.where(dumm_columns == dataset['keyword'][index])[0][0]
                dummies.iloc[index, [column]] = 1
            else:
                dummies.iloc[index, [0]] = 1
    
        return dummies
    
    def __len__(self):
        return self.len
    
    def slang_replace_(self, string):
        keyword_processor = KeywordProcessor()
        keyword_processor.add_keyword('u', 'you')
        keyword_processor.add_keyword('fvck', 'fuck')
        
        new_string = keyword_processor.replace_keywords(string)
        return new_string
    
    
    def clean_text_(self, string):
        
        string = string.strip()
        string = self.slang_replace_(string)
        
        for replace in self.replacements:
            string = string.replace(replace, ' ')
        string_splitted = string.split()
        string_result   = []
        
        for index in range(len(string_splitted)):
            sub_string = string_splitted[index] 
            
            if not(sub_string in stop_words or re.search("\d", sub_string) 
                   or re.search(u"[\x80-\x9f]", sub_string) or sub_string == 'co' or len(sub_string) == 1):
                
                if self.lemmatize:
                    string = self.lemmatizer.lemmatize(sub_string)

                string = string.lower()
                string_temp = re.sub(r'([a-z])\1+\1+', r'\1', string)
                string_result.append(string_temp)
                
        return '[CLS] ' + ' '.join(string_result)
        
        
    def __getitem__(self, index):
    
        text   = self.dataset.text[index]
        target = self.target[index]
        
        if self.prepear: 
            text_transformed = self.clean_text_(text)
    
        if self.include_keyword:
            keyword_array = torch.tensor(self.keywords.iloc[index].to_numpy())
            return text_transformed, keyword_array, target
        
        
        return text_transformed, target

# %%
def data_augmentation(train_df):
    augmentation_df_1 = train_df
#     augmentation_df_2 = train_df
    augmentor = RandAugment([
        en.add_synonyms,
        en.add_hyponyms,
        en.add_misspelling,
        en.swap_words,
        en.add_contractions,
        ], n=1, m=20, shuffle=False)
    
#     augmentor_2 = RandAugment([
#         en.add_synonyms,
#         en.add_hyponyms,
#         en.add_misspelling,
#         en.swap_words,
#         en.add_contractions,
#         ], n=1, m=50, shuffle=False)
    
    text = augmentation_df_1.text.tolist()
    augmentation_list_1 = []
#     augmentation_list_2 = []
    
    for sentence in text:
        for tx in augmentor:
            augment_text = tx(sentence)
            augmentation_list_1.append(augment_text)
            
#         for tx in augmentor_2:
#             augment_text = tx(sentence)
#             augmentation_list_2.append(augment_text)
            
    augmentation_df_1.loc[:, 'text'] = augmentation_list_1
#     augmentation_df_2.loc[:, 'text'] = augmentation_list_2
#     result_df = pd.concat([augmentation_df_1, train_df, augmentation_df_2], axis=0, ignore_index=True)
    result_df = pd.concat([augmentation_df_1, train_df], axis=0, ignore_index=True)
    
    return result_df.reset_index(drop=True)

# %%
train_df = df.iloc[:6613]
test_df  = df.iloc[6613:].reset_index(drop=True)
train_df

# %%
# train_df = data_augmentation(train_df)
# train_df

# %%
X_train, y_train = train_df.drop('target', axis=1), train_df.target
X_test, y_test   = test_df.drop('target', axis=1), test_df.target

# %%
train_dataset = TweetsDataset(X_train, y_train, True, dumm_columns)
test_dataset  = TweetsDataset(X_test, y_test, True, dumm_columns)

# %%
for i in range(1, 100):
    print(train_dataset.__getitem__(i)[0])

# %%
X_train.shape, X_test.shape

# %%
# AutoModel.from_pretrained("vinai/bertweet-base")

# %%
class Model_BertBased(nn.Module):
    
    def __init__(self):
        super().__init__()
        
        self.bert = AutoModel.from_pretrained("rabindralamsal/finetuned-bertweet-sentiment-analysis")
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features = 769, out_features = 1, bias = True),
            nn.Sigmoid()
        )
        
        self.keyword_classifier = nn.Sequential(
            nn.Linear(in_features = 166, out_features = 1, bias = True),
            nn.LeakyReLU()
        )
        
    def forward(self, input_ids, attention, keyword, freeze):
        
        if freeze:
            for param in self.bert.parameters():
                param.requires_grad = False 
        else: 
             for param in self.bert.parameters():
                param.requires_grad = True

        X = self.bert(input_ids, attention)
        keyword  = self.keyword_classifier(keyword.to(torch.float32))
        X_concat = torch.cat((X.pooler_output, keyword), dim = 1)
        
        
        X = self.classifier(X_concat)
        return torch.squeeze(X)

# %%
def train(model, lr, train_dataset, test_dataset, num_epochs=15, max_length = 15, 
          batch_size = 64, freeze=True, weights_decay = 0):
    
    model.to(device)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr, weight_decay = weights_decay)
    criterion = nn.BCELoss()
    
    bert_tokenizer  = AutoTokenizer.from_pretrained("rabindralamsal/finetuned-bertweet-sentiment-analysis")
    
    train_loader = DataLoader(train_dataset, batch_size)
    test_loader  = DataLoader(test_dataset, batch_size)
    
    scheduler = ExponentialLR(optimizer, gamma=0.5)
#     scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
 

    for epoch in range(num_epochs):
        
        running_loss = 0.0
        train_count  = 0
        
        running_loss_test = 0.0
        train_count_test  = 0
        
        for text, keywords, target in train_loader:
            
            optimizer.zero_grad()
            
            text = bert_tokenizer.batch_encode_plus(text, max_length=max_length, 
                                               truncation=True, 
                                               padding='max_length')
            
            input_ids = torch.tensor(text.input_ids)
            attention = torch.tensor(text.attention_mask)
        
            output = model(input_ids.to(device), attention.to(device),  keywords.to(device), freeze)
            loss   = criterion(output.to(torch.float32).to(device), target.to(torch.float32).to(device))
            loss.backward()
            
            optimizer.step()
            
            running_loss += loss.item()
            train_count  += 1
            
            
        for text, keywords, target in test_loader:
            
            with torch.no_grad():
                text = bert_tokenizer.batch_encode_plus(text, max_length=30, 
                                               truncation=True, 
                                               padding='max_length')
            
                input_ids = torch.tensor(text.input_ids)
                attention = torch.tensor(text.attention_mask)
                
                
                output = model(input_ids.to(device), attention.to(device),  keywords.to(device), freeze)
                loss   = criterion(output.to(torch.float32).to(device), target.to(torch.float32).to(device))

                running_loss_test += loss.item()
                train_count_test  += 1
                
        scheduler.step()
    
        print('Epoch: ', epoch)
        print('Train_loss: ', running_loss / train_count)
        print('Test_loss: ', running_loss_test / train_count_test, '\n\n')
        
        experiment.log_metric("train_loss", running_loss / train_count, step=epoch)
        experiment.log_metric("test_loss", running_loss_test / train_count_test, step=epoch)

# %%
model = Model_BertBased()

# %%
lr = 0.1
num_epochs = 50
max_length = 15
batch_size = 64
treshold = 0.47

hyper_params = {
    "learning_rate": lr,
    "num_epochs": num_epochs,
    "max_length": max_length, 
    "batch_size": batch_size,
    'treshold': treshold,
}
experiment.log_parameters(hyper_params)

train(model, lr, train_dataset, test_dataset,  num_epochs, 
      max_length, batch_size, freeze=True)

# %%
model_copy = model

# %%
lr = 1e-5
num_epochs = 1
max_length = 15
batch_size = 64

train(model_copy, lr, train_dataset, test_dataset,  num_epochs, max_length, 
      batch_size, freeze=False, weights_decay=0.01)
# Out:
# Epoch:  0
# Train_loss:  0.4077570212001984
# Test_loss:  0.48740207962691784

# %%
def batch_predict(model, test_dataset):
    
    test_loader = DataLoader(test_dataset, batch_size=64)
    bert_tokenizer  = AutoTokenizer.from_pretrained("vinai/bertweet-base")
    
    model.to(device)
    results = []
    targets = []

    for text, keywords, target in test_loader:
        
            with torch.no_grad():
                text = bert_tokenizer.batch_encode_plus(text, max_length=15, 
                                               truncation=True, 
                                               padding='max_length')
                
                input_ids = torch.tensor(text.input_ids)
                attention = torch.tensor(text.attention_mask)
            
                output  = model(input_ids.to(device), attention.to(device),  keywords.to(device), False)

                results += output.tolist()
                targets += target.tolist()
    
    return results, targets

# %%
results = batch_predict(model, test_dataset)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
preds  = np.array(results[0])
target = np.array(results[1])

preds = np.where(preds > 0.42, 1, 0)

f1_score(target, preds)
# Out:
# 0.7613882863340564

# %%
experiment.log_metric("f1_score", f1_score(target, preds), step=0)

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/zanzibara1961/twitter-threat-classification/29bcc2109ae64a2b99bb464216b74ff4
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     f1_score        : 0.7745098039215685
# COMET INFO:     test_loss [16]  : (0.3924035392701626, 0.5645373128354549)
# COMET INFO:     train_loss [16] : (0.4249946947854299, 0.6904508740856097)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 64
# COMET INFO:     learning_rate : 0.1
# COMET INFO:     max_length    : 15
# COMET INFO:     num_epochs    : 15
# COMET INFO:     treshold      : 0.47
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     source_code         : 1
# COMET INFO: ---------------------------
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: tensorflow, tensorboard, sklearn, torch. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 2 file(s), remaining 107.97 KB/371.97 KB

# %% [markdown]
# # Prediction Submitting

# %%
test_df = pd.read_csv('test.csv', index_col = 'id').reset_index(drop=True)
test_df
# Out:
#      keyword location                                               text
# 0        NaN      NaN                 Just happened a terrible car crash
# 1        NaN      NaN  Heard about #earthquake is different cities, s...
# 2        NaN      NaN  there is a forest fire at spot pond, geese are...
# 3        NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4        NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
# ...      ...      ...                                                ...
# 3258     NaN      NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259     NaN      NaN  Storm in RI worse than last hurricane. My city...
# 3260     NaN      NaN  Green Line derailment in Chicago http://t.co/U...
# 3261     NaN      NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262     NaN      NaN  #CityofCalgary has activated its Municipal Eme...
#
# [3263 rows x 3 columns]

# %%
test_df.loc[test_df['keyword'].isnull(), 'keyword'] = 'Null'

test_df.keyword = test_df.keyword.str.replace('%20', '')

stemmer = PorterStemmer()

test_df.keyword = test_df.keyword.apply(lambda x: stemmer.stem(x))

test_df
# Out:
#      keyword location                                               text
# 0       null      NaN                 Just happened a terrible car crash
# 1       null      NaN  Heard about #earthquake is different cities, s...
# 2       null      NaN  there is a forest fire at spot pond, geese are...
# 3       null      NaN           Apocalypse lighting. #Spokane #wildfires
# 4       null      NaN      Typhoon Soudelor kills 28 in China and Taiwan
# ...      ...      ...                                                ...
# 3258    null      NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259    null      NaN  Storm in RI worse than last hurricane. My city...
# 3260    null      NaN  Green Line derailment in Chicago http://t.co/U...
# 3261    null      NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262    null      NaN  #CityofCalgary has activated its Municipal Eme...
#
# [3263 rows x 3 columns]

# %%
test_df['target'] = 0
test_df
# Out:
#      keyword location                                               text  \
# 0       null      NaN                 Just happened a terrible car crash
# 1       null      NaN  Heard about #earthquake is different cities, s...
# 2       null      NaN  there is a forest fire at spot pond, geese are...
# 3       null      NaN           Apocalypse lighting. #Spokane #wildfires
# 4       null      NaN      Typhoon Soudelor kills 28 in China and Taiwan
# ...      ...      ...                                                ...
# 3258    null      NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259    null      NaN  Storm in RI worse than last hurricane. My city...
# 3260    null      NaN  Green Line derailment in Chicago http://t.co/U...
# 3261    null      NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262    null      NaN  #CityofCalgary has activated its Municipal Eme...
#
#       target
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 3258       0
# 3259       0
# 3260       0
# 3261       0
# 3262       0
#
# [3263 rows x 4 columns]

# %%
X_test, y_test = test_df.drop('target', axis=1), test_df.target
test_dataset = TweetsDataset(X_test, y_test, True, dumm_columns)

# %%
for i in range(1, 1000):
    print(test_dataset.__getitem__(i)[0])
# Out:
# [CLS] heard earthquake different cities, stay safe everyone
# [CLS] forest fire spot pond, goose fleeing across street, cannot save
# [CLS] apocalypse lighting spokane wildfire
# [CLS] typhoon soudelor kill china taiwan
# [CLS] we shaking it earthquake
# [CLS] they probably still show life arsenal yesterday, eh eh
# [CLS] hey how
# [CLS] what nice hat
# [CLS] fuck
# [CLS] no like cold
# [CLS] no don
# [CLS] no tell
# [CLS] what
# [CLS] awesome
# [CLS] birmingham wholesale market ablaze bbc news fire break birmingham wholesale market irwqcezweu
# [CLS] sunkxssedharry wear short race ablaze
# [CLS] previouslyondoyintv toke marriage crisis set nigerian twitter ablaze
# [CLS] check yduixefipe nsfw
# [CLS] psa splitting personality techie follow ablaze burners follow ablaze
# [CLS] beware world ablaze sierra leone amp guap
# [CLS] burning man ablaze turban diva hodwosamws via etsy
# [CLS] not dis song people take thing run smh eye opener though he set game ablaze cyhitheprynce
# [CLS] rape victim dy set ablaze year old girl died burn injury set
# [CLS] setting myself ablaze
# [CLS] ctvtoronto bin front field house wer set ablaze day flame went rite hydro pole wonder
# [CLS] nowplaying alfons ablaze puls radio pulsradio
# [CLS] burning rahm let hope city hall build giant wooden mayoral effigy foot tall amp set ablaze john kass
# [CLS] philippaeilhart dhublath hurt eye ablaze insulted anger
# [CLS] accident cleared paturnpike patp eb pa cranberry slow back traffic
# [CLS] just got love burning self damn curling wand swear someone need take away cuase accident prone
# [CLS] hate badging shit accident
# [CLS] car recorder zeroedge dual lens car camera vehicle traffic driving history accident camcorder large re
# [CLS] coincidence or curse still unresolved secrets from past accident
# [CLS] traffic southe roadpol east accident near lewes kingston roundabout rather
# [CLS] sakuma en if pretend feel certain way feeling become genuine accident hei darker black manga anime
# [CLS] liked youtube video ujriaivqln minecraft night lucky block mod bob apocalypse wither amp more mod showcase
# [CLS] universal order of armageddon
# [CLS] patent pending stream armageddon ep
# [CLS] armageddon london
# [CLS] hitchbot heard might rise ash armageddon go hitchbot like true superstar
# [CLS] turkey invades israel halfway armageddon
# [CLS] remember crowd around baggage carousel like armageddon bag last remaining food item earth animal
# [CLS] never compromise even face armageddon watchmen
# [CLS] mustread vladimir putin issues major warning but is it too late to escape armageddon pcraigroberts us rus
# [CLS] you da one mtvsummerstar videoveranomtv mtvhottest britney spears lana del rey
# [CLS] if build army lion leader dog fight lion die like dog
# [CLS] one direction is pick fan army directioners
# [CLS] shark army black date stainless steel quartz men sport watch full read ebay
# [CLS] beyonce is pick thoyhrhkfj fan army beyhive
# [CLS] seconds summer is pick fan army
# [CLS] beyonce is pick fan army beyhive
# [CLS] victorinox swiss army date women rubber mop watch
# [CLS] hope salvation army least gave tax receipt
# [CLS] one direction is pick fan army directioners
# [CLS] one direction is pick fan army directioners
# [CLS] one direction is pick fan army directioners
# [CLS] check data upper wabash reservoir louisvilleusace site hqqlquqzmd
# [CLS] answer therefore came pas sixteenth year go forth head army
# [CLS] one direction is pick fan army directioners
# [CLS] seconds summer is pick fan army
# [CLS] cheesehead report arson charge filed jackson county house fire
# [CLS] arson suspect linked fire caught northern california
# [CLS] israeli police unable solve case duma arson attack
# [CLS] shock report muslims setting wildfires across american west arson jihad
# [CLS] pnuts mama be strong it time like arson happens push thru past felony stage
# [CLS] breakingnews mourning notice stabbing arson victim stir israel posters ktkdrgvhgx rome
# [CLS] mourning notice stabbing arson victim stir israel posters shira banki
# [CLS] rt opus elliott probation two year pay fine
# [CLS] rt saginaw police sketch person interest saginaw arson
# [CLS] fire that destroyed charlton winery ruled to be arson
# [CLS] wehtwtvwlocal trial date set man charged arson burglary
# [CLS] man charged connection shawnee arson burglary olathe kan man court wednesday accused
# [CLS] steele police arrest possible arson investigation
# [CLS] vixuhn rip arson
# [CLS] arson suspect linked fire caught northern california
# [CLS] rt theadvocatemag owner chicago area gay bar admits arson scheme whtmwtgroj lgbt
# [CLS] lgbtq news owner chicago area gay bar admits arson scheme frank elliott pleaded via theadvocatemag
# [CLS] mourning notice stabbing arson victim stir israel posters shira banki
# [CLS] contra costa co authority arrest suspected serial arsonist authorities believe lbqldykgdp
# [CLS] owner chicago area gay bar admits arson scheme frank elliott pleaded guilty hiring arsonist
# [CLS] local arsonist cloudy goldrush man shit
# [CLS] mo way say carry vqzruthrnu
# [CLS] arsonist sets nyc vegetarian restaurant fire police newyork
# [CLS] arsonist torch house getaway vehicle police say surrey leader richardgearl
# [CLS] safyuan already threw away letter tho
# [CLS] hotel arsonist caused damage an arsonist jailed court hear hngddbhewa
# [CLS] suspected serial arsonist east bay arrest nightbeattv kbcwtv veronicadlcruz
# [CLS] arsonist mc christ walk toronto columbus gospel
# [CLS] bitch dont get slapped
# [CLS] trap vodka new fave vine
# [CLS] suspected serial arsonist arrested norcal mjxbygejyl
# [CLS] japan mark anniversary atomic bombing hiroshima
# [CLS] japan marks anniversary hiroshima atomic bombing the associated press via nyt
# [CLS] the sanitised narrative hiroshima atomic bombing japan
# [CLS] japan mark anniversary hiroshima atomic bombing bells tolled hiroshima thursday japan marke iqairpdihg
# [CLS] japan mark anniversary hiroshima atomic bombing mlzxmgvuih
# [CLS] yr since atomic bombing hiroshima terrible mass murder
# [CLS] breaking news australia collapse hapless trent bridge
# [CLS] project syndicate marshall plan united states
# [CLS] new two giant crane holding bridge collapse nearby home
# [CLS] akinwunmiambode urgentthere currently storey building church stop oworoshoki third mainland bridge likely collapse
# [CLS] throwback thursday more thoughts about citizen media during minneapolis bridge collapse disaster tbt
# [CLS] ashes collapse trent bridge among worst history england bundled australia
# [CLS] two giant crane holding bridge collapse nearby home
# [CLS] throwback thursday minneapolis bridge collapse amp citizen journalism tbt ibmqvwrvyz
# [CLS] berggrueninst berggruen institute member dambisamoyo problem us infrastructure prosyn
# [CLS] australia collapse trent bridge twitter on first morning fourth ashes test
# [CLS] shane warne ricky ponting shocked australia batting collapse trent bridge
# [CLS] injured missing bridge collapse central mexico
# [CLS] australia ashes disaster collapse unfolded trent bridge uqeteeltvu telegraph
# [CLS] sport shane warne ricky ponting shocked australia batting collapse trent bridge australian grea
# [CLS] injured bridge collapse swiss kosher hotel the accident occurred tuesday metropol hotel
# [CLS] scary thought happened today would teenager taking selfies front burning building
# [CLS] this sounds like song you would hear in movie where they are walking away from burning buildings and cars and shit
# [CLS] ctvkathyle news run burning building
# [CLS] forestservice rt dhsscitech firefighters run burning work tech kybqcsvrza
# [CLS] like folk said building city trying get information asap prevent
# [CLS] like ppl burning building knowing originally created
# [CLS] kou like cash register buildings burning
# [CLS] thehill what hate crime it looney libs always burning building vandalzing private property
# [CLS] rule long life go burning building jump perfectly good airplane awaken sleeping giant
# [CLS] port coquitlam fire burning several business
# [CLS] speechgirlam on par caring sick helping people move talking movie rescuing people burning building
# [CLS] travdave kornbread icu especially happened really nothing tear burning building save city money real
# [CLS] the fire brigade play guy music burning building put flame
# [CLS] two building burn alarm antioch fire two building burning alarm fire delta
# [CLS] denisleary not sure folk rush burning building grateful trueheroes
# [CLS] jane kelsey fire economy aug old govt buildings wgton the context amp driver tpp tradeinservicesagreement
# [CLS] failure exist change direction alejandro jodorowsky via building fire
# [CLS] security want help case emergency like building fire shooter building leaving tho
# [CLS] blainescronuts thats would building fire
# [CLS] fucking apartment across street fire right fuckin firetrucks wtf second time building caught fire
# [CLS] it testimony human spirit u set fire office building sunday night
# [CLS] there multiple building fire in downtown hinton ok the fire threatening level entire block
# [CLS] dnr res building shelled amp fire gorlovka tonight civilian casualty jan july killed incl child wounded
# [CLS] gilsimmons lightening struck amp unit building development fire groton ct check fb wall recent post
# [CLS] taiz houthi saleh indiscriminate shelling castle set tahreer st building fire yemen
# [CLS] buildings fire behind tisa niceville tristapnwfdn
# [CLS] two building involved fire street manchester wmur
# [CLS] agricultural buildings fire aldwark nyorks fire amp rescue service still grim news fewer piglet caught
# [CLS] multiple firefighter hospitalized fighting fire manchester nh
# [CLS] there multiple building fire in downtown hinton ok the fire threatening level entire block
# [CLS] my happy pensioner stories safe buildings watching report unsafe cladding catching fire melbourne
# [CLS] multiple house building fire kalispell
# [CLS] family heartbroken mobile home nellis amp cheyenne burned fire kids ready go back school
# [CLS] burned finger
# [CLS] this burned stake
# [CLS] let tell brandace brought today ntc heat survived burned
# [CLS] irsolichin potus the last city everyone burned death terrorism grandest scale
# [CLS] kyra elizabethh back break light burned gotta show next day
# [CLS] realdonaldtrump been burned republicans many time least talking thing important u good luck
# [CLS] burned calorie minute total body cardio myfitnesspal
# [CLS] corey white talking dat shit got burned curlin iron black woman neck
# [CLS] blackhatwriter yeah going home computer next two weekend getting really burned really quick
# [CLS] pdleague sorry crit sure matter prob cuz burned
# [CLS] got rhyme bible got psalm and like prodigal son returned anyone stepping get burned
# [CLS] widouglass kurlyw adamrubinespn nationals welp dunce got burned
# [CLS] omg last week accidentally burned cigarette lol would
# [CLS] adamrubinespn know burned week ago similar spot getting pitch save inn
# [CLS] keep calling crazy cause never learned stop loving fire got
# [CLS] proud heart played stabbed cheated burned broken but somehow still work
# [CLS] hermancranston wired all fire burning firefighter budget fsganfrgjh
# [CLS] psa chopped jalapeno amp finger burning lava fire painful hr this first wear glove pepper hell
# [CLS] geoengineering burning fossil fuel making global weather unstable with temp biggest flood past year
# [CLS] sar giuliani currently burning skin
# [CLS] yes we comrade sweat seeking calorie burning cardio torture we need support get smile nod wave
# [CLS] wow legion slouching towards the broken isles warlords draenor close enough the burning crusad rkpmomqmui
# [CLS] thevenskus led killer workout today thesweatshoppe core burning now gymtime worktime auditiontime roccotime nobs
# [CLS] peddle floorboard end four door burning backroad song park pile baby watch step
# [CLS] burning bridge forte
# [CLS] rt real burn book entry ca fuck place always burning
# [CLS] fear fever can feel feel fire burning belo ow it gonna trick ya swallow o ole mtvhottest justin bieber
# [CLS] burning legion returned
# [CLS] the arab autocracy burning house via theeconomist
# [CLS] tarekfatah burning enemity pakistan sure burn
# [CLS] put ton sunscreen still burning
# [CLS] blizzard detail new dungeons raids world warcraft legion the burning
# [CLS] what accomplishing burning killing building
# [CLS] amp common breaker trip threshold protect awg wire commonly used building burning power outlet result
# [CLS] burning buildings keep the flames lit
# [CLS] three alarm fire burning antioch apartment complex
# [CLS] rockbottomradfm is one challenge tough enough rescuing people burning building
# [CLS] mrjamesob getting rid every last drop life gone crawl burning building life matter jakey
# [CLS] firefighters brave people opinion bc clare know could save ppl burning building house salute
# [CLS] the rocky fire burning ca still threatening building largest state amp one nearly dozen burning
# [CLS] liked youtube video mega man zx ost ogre claw area burning buildings
# [CLS] denisleary not sure folk rush burning building grateful trueheroes
# [CLS] trubeque destruction magic fine go burning building
# [CLS] high skies burning buildings nowplaying
# [CLS] what used drone help firefighter lead people burning building help put fire
# [CLS] when attack pp attack woman health amp attack woman health attack america health
# [CLS] soaring temperature southern us state causing bush fire pity scotgov allow rain scotland tweetlikekez
# [CLS] you know hot bush fire right near villa
# [CLS] bushfire cause first victim albania the multiple fire albania caused first vict bush
# [CLS] drove past field fire yesterday reminded bush fire used get south africa
# [CLS] bush food fire toflxodyrx
# [CLS] watch mother nature halt australia blue mountains bushfire
# [CLS] jiminswang say bush fire au reason hot
# [CLS] bushfire cause first victim albania the multiple fire albania caused first vict bush
# [CLS] if like goat dislike bush fire probably video
# [CLS] pamelamueller time it honour privlege pray witnessed bush fire living australia
# [CLS] therealpbarry how much erupting volcano bush fire raging put atmosphere none believer mention
# [CLS] all eugene fire gotta make think hashtag conspiracy hashtag population control hashtag bush
# [CLS] warfighting robots could reduce civilian casualties so calling ban now is premature
# [CLS] let hope concert end zero casualty amen
# [CLS] american weapons support are fueling bloody air war yemen
# [CLS] more woman child casualty afghan violence
# [CLS] gtiso fair enough change always unfortunate casualty like nzmorningreport utilises welly amp aucklnd we see
# [CLS] memorial day year hiroshima nagasaki august wth total casualty god forgive
# [CLS] warfighting robots could reduce civilian casualties so calling ban now is premature trngqopbdl
# [CLS] esksf always casualty right thing especially going cost bos money
# [CLS] josh daniel mikegiarrusso foxnews think bunch untrained people firing back going cause casualty
# [CLS] obama lambasted respected amp would trump prefer civilian casualty gop maddow
# [CLS] jimw nm kurtschlichter here thing predicting up to million american casualties forget goddamn japanese
# [CLS] american weapons support are fueling bloody air war yemen
# [CLS] let appreciate group people everyone hate much police prevented mass casualty today nashville
# [CLS] dontestallworth stevesgoddard look casualty iwo jima okinawa number dead side see
# [CLS] cameron surname the allies forecast invasion japan minimum million casualty minimum
# [CLS] rx casualty vpzedd daintt call
# [CLS] legaljobs litigation attorney scottsdale az claims specialist ii casualty bodily injury the jobs
# [CLS] social casualty
# [CLS] maccocktail the first casualty war truth hiram johnson died day tony blairs case died war
# [CLS] georgian wine become casualty russia political campaign ukraine
# [CLS] bruminthecity oh coffee espresso po casualty today busiest thurs ever come perfect coffee house
# [CLS] associated agencies inc hiring property amp casualty account manager job rollingmeadows insurance
# [CLS] documenting climate change first major casualty via greenharvard
# [CLS] canceling deal warships france agrees repay russia via nytimes
# [CLS] charlie casualty ash jdlymguhww
# [CLS] keep alive sound intensity level catering keeping auditory effect casualty insurance hcxvneoav
# [CLS] give money hear social casualty live mtvhottest buck give
# [CLS] vpzedd reach skype
# [CLS] please read casualty fan let u know amp help spread word retweeting dm scriptettesar info hdrbtjrohb
# [CLS] business casualty
# [CLS] datshemmings moi est plutot disconnected reason close stranger heartbreak girl reject social casualty ufhguhfidt
# [CLS] fox news biggest medium catastrophe american history people love living lie
# [CLS] twist sony ultimate preparedness library prepare yourself for any catastrophe over
# [CLS] buzzfeed stannis evil book got catastrophe saying
# [CLS] shaneryanhere catastrophe amazon prime
# [CLS] you wonderful person thomasistrash thomasistrash
# [CLS] now quietly waiting catastrophe personality seem beautiful interesting modern
# [CLS] gaza the summer catastrophe gaza palestine israel bds
# [CLS] caradelevingne mother chucker catastrophe so much hotness one room cope swifties
# [CLS] twlldun peterjukes it good piece and agree failure post war planning catastrophe
# [CLS] sorry kylie pretty sure james ate bruce morning catastrophe
# [CLS] robdelaney desperate watch last episode catastrophe how get uk
# [CLS] barackobama hello mr president really big problem puerto rico regarding water situation like catastrophe
# [CLS] alaska wolves face catastrophe alexander archipelagowolves population plummeted yr be voice vcpkdbnsfp
# [CLS] two show loved summer catastrophe unreal
# [CLS] vaunwilmott paystara agrees catastrophic loss love barn scene short shirtless michael dominion
# [CLS] something catastrophic is coming should we tune out
# [CLS] wp following catastrophic event united states decimated the president prepares first post
# [CLS] johngreen the catastrophic history
# [CLS] if rise wage going catastrophic impact wage structure what fuck automation going
# [CLS] unitednyblogs insidecityhall nyclass ouch he need explain nyclass hate mailer catastrophic fail
# [CLS] the catastrophic effects hiroshima nagasaki atomic bombings still being felt today
# [CLS] how society respond looming crisis uncertain timing catastrophic proportion
# [CLS] dear carlyfiorina will anyone family alive climatechange gopdebate feelthebern
# [CLS] cancer everything seems catastrophic feel worse hit rock bottom you recover you start after got
# [CLS] jim rickards blog catastrophic outcomes may come faster than expecte
# [CLS] stop extreme regulations that hurt the middle class
# [CLS] laladeviluke consequence could catastrophic also informed security mute primarily
# [CLS] gaming learning legacy catastrophic eruption fifteen mile high plume ash the eruption wh
# [CLS] want sell boat car truck
# ...
# [CLS] ok two favorite thing collided one great ht literarycakes
# [CLS] call car v fed ex truck head collision mile marker prayers family get scene
# [CLS] motorcyclist bicyclist injured denver collision broadway
# [CLS] motorcyclist bicyclist injured denver collision broadway at least two people taken
# [CLS] traffic collision ambulance enroute florin rd franklin blvd south sac
# [CLS] the denver post motorcyclist bicyclist injured denver collision broadway
# [CLS] collision damn
# [CLS] marin trfc collision unkn inj yqjvevhszx
# [CLS] riverside con con trfc collision unkn inj qqmlkvgpqk
# [CLS] techerit anti collision rear gadget technology
# [CLS] anti collision rear innovation gadget
# [CLS] mom fight recover hospital fiery car crash kid miss home
# [CLS] no citation billings police officer caused broadwater crash aahyoeitzl
# [CLS] our little angel banjo pilon dy skateboarding crash wamberal at weekend year old
# [CLS] lol guy whipping double yellow line mustang crash curb light pole sn
# [CLS] new post india train crash kills dozens
# [CLS] crash
# [CLS] crash matrix themercedesx with minivan
# [CLS] non power schools best shot crash college football playoff
# [CLS] this hilarious look we got hairity rainbow crash spitty pie spikebot
# [CLS] thieves crash dealership gate steal four vehicle killeen
# [CLS] time enjoy summer crash course two week never take summer class that lie
# [CLS] portmoody clarke rd hill blocked crash past seaview traffic back kemsley take como lake gatensbury get around
# [CLS] natethewolf car v motorcycle crash fairport nine
# [CLS] learn cpanel join cpanel crash course
# [CLS] emily sterlingknight joeylawrence abcfmelissajoey car crash pretty fun film melissaandjoeychat
# [CLS] news injured school bus crash bordentown details
# [CLS] the crash and new depression the seeds for the next crisis have already been sown
# [CLS] husband back edinburgh crashed one young adult got raging temperature gone ve not had any tea
# [CLS] rip whoevers face crashed front work wish could helped
# [CLS] almost crashed listening walk moon but dont care love it
# [CLS] dometufnellpark do know curfew havoc fest sunday please
# [CLS] sex themed book given curfew germany
# [CLS] big hanging out no curfew
# [CLS] happy report quite tropics cyclone development expected time cbsmiami miamiherald
# [CLS] here come next episode scorpion cyclone scorpioncbs
# [CLS] the revival cyclone football begin today be september
# [CLS] an appeal by cardinal charles bo sdb cnua dear brothers sisters the recent cyclone massive
# [CLS] cyclone hit skye qzyermrqtw
# [CLS] orochinagicom gigatech cyclone
# [CLS] severe weather bulletin no for typhoon soudelor tropical cyclone warning issued at pm
# [CLS] first time everything coney island cyclone
# [CLS] aliyeskii wquddin maungkyawnu drkhubybe nslwin ibrahimdubashi mdskar zarnikyaw after cyclone
# [CLS] erpestar aint bitch girl popobawa revolves around cyclone
# [CLS] weather tropicalweather tropical cyclone tracking update aug tropicalupdate
# [CLS] is hurricane typhoon no matter one also cyclone
# [CLS] waige driving like badass scorpionpilot cyclone scorpioncbs
# [CLS] raleigh cyclone gear mountain bike sportinggoods llefhhggrl
# [CLS] rt severe weather bulletin no for typhoon soudelor tropical cyclone warning issued at pm
# [CLS] red tropical cyclone alert soudelor china northern mariana islands aug
# [CLS] localeventcountdown curtain open the black cyclone shelby ticket amp info rstoday
# [CLS] may rodder super stock keeling mustang barracuda riviera cyclone
# [CLS] damage done how recover from negative social media update smexaminer
# [CLS] beforeitsnews is called damage control don be fooled folks the perps will just come up with plan
# [CLS] frauncestavern named one historic property granted nygovcuomo repair sandy damage
# [CLS] globepolitics extreme position lack debate pandering hard right increase divide corrodes trust damage goodwill
# [CLS] limited damage put run board nyy
# [CLS] never riding gaymaro would damage reputation
# [CLS] alpine city park vandalized damage
# [CLS] got first damage today fuck
# [CLS] vzwsupport zero damage horrible product
# [CLS] gatorgmuzik fettilootch is slanglucci oppressions greatest danger coming soon the album
# [CLS] used really think danger gonna movie
# [CLS] think it realistic scully finally home sfe wanted go danger hipsbeforehands
# [CLS] onceaho empire girl vote abella danger adult empire running first ever hunt emp alwaysaho
# [CLS] free book blow suspense danger anger love importantly
# [CLS] in post today talk danger interruption do annoy
# [CLS] theelmagoo gopteens foxnews pattonoswalt anyone actually play drinking game serious danger alcohol poisoning
# [CLS] pukesmoothie understand why would put u danger
# [CLS] mlp delrim please tell might danger knew knew
# [CLS] the devil wears prada still one favourite film
# [CLS] allen west obama clear present danger republic
# [CLS] fresenius said put patient life danger time whats happening same like bigger violation ppe
# [CLS] james may not amusicvideoaday king ruckus there lot business operate outskirt amp never feel danger
# [CLS] unitedutilities happy received text parasite danger transplantee amp virus kill kidney
# [CLS] last retweet hope drop dead
# [CLS] once thought dead google glass gets second coming though considered epic failure according maker recent patent
# [CLS] dead essxzdtcqj
# [CLS] possum problem dead duck
# [CLS] hope ross amp val dead emmerdale summerfate
# [CLS] dead as truth pay shit gone use
# [CLS] emmerdale summerfate intense can believe val dead
# [CLS] nah emmerdale mikeparractor ross dead know unconscious dramatic tease
# [CLS] ross better dead emmerdale
# [CLS] no village hotty dead emmerdale
# [CLS] mikeparractor no believing ross dead lvolntswdz
# [CLS] mikeparractor ross dead shall never watch emmerdale heartbroken
# [CLS] reckon ross dead actually said pete killed brother ross survived much die
# [CLS] please tell ross actually dead hope playing u next episode emmerdale
# [CLS] flood two people dead house destroyed kaduna
# [CLS] if boyfriend ex feeling dont talk to him don follow he dead he exist niggah
# [CLS] for everyone know chris prater struck train morning pronounced dead scene prayers family
# [CLS] tonedidit real nah mother dead wrong
# [CLS] way ross dead emmerdale
# [CLS] what an incredible character my heart is broken that he is actually dead ripross we will miss you lgqmdnavdf
# [CLS] baeffee randompelar black death black death whoo
# [CLS] liked youtube video camp out bunk disney channel
# [CLS] obama don worry good iranians kidding death america chant the bad one like republicans
# [CLS] microsoft xbox console rrod red ring death as is for parts or repair full read
# [CLS] this headache death
# [CLS] itristontyler confession little hamster room cold froze death oops
# [CLS] this wall going death due year water leak lack
# [CLS] the iran deal will result in terrorism and death truth revolt
# [CLS] swearyg it look like death star
# [CLS] death certainty life
# [CLS] single death tradery many death statistic
# [CLS] spirituality born again spiritual awakening and near death experiences charlesfrize frizemedia dynamicfrize
# [CLS] kaay paat actually death take way longer think
# [CLS] day look like death see mo city chick fil today
# [CLS] deaths
# [CLS] betrayedhunter reading paused came across couple death began read deeper
# [CLS] deaths
# [CLS] bigamist first wife charged death second pregnant wife child
# [CLS] health fact women account smoking death
# [CLS] series death seemed one right another book seems month pas death liz
# [CLS] bootlegalbano shaunking know he profit death people claim fighting he make sick
# [CLS] mohammedzismail death regular gunsmissilesbombs warfare bomb used war
# [CLS] infections driving neonatal death health minister guyana imugnxrebn
# [CLS] bigamist wife charged death pregnant wife child mother nephew
# [CLS] msha stepping enforcement mining death via elkodaily
# [CLS] bigamist first wife charged death second pregnant wife child mothe
# [CLS] is wing part enough solve mystery
# [CLS] debris found indian ocean could malaysia flight vuojprkuax
# [CLS] bbc news reunion debris missing malaysia flight
# [CLS] news island wreckage is from missing malaysian jet officials debris found reunion island flight
# [CLS] hopefully bring closure family malaysian pm confirms debris missing flight
# [CLS] rì©union debris is almost surely from flight officials say
# [CLS] aus aircraft debris found island malaysia confirms abc
# [CLS] aircraft debris found la reunion missing malaysia airlines yklruimisd
# [CLS] with authority increasingly confident airplane debris recovered wednesday come official analysis set begin
# [CLS] investigators plane debris is conclusively from gadget tech
# [CLS] top story reunion debris missing plane bbc news see
# [CLS] per malaysia pm piece debris conclusively part wing more right
# [CLS] interesting aircraft debris found la reunion missing malaysia airlines abc please rt
# [CLS] rmt playing jackson browne before deluge listeners requests on
# [CLS] liquidslap name ja rule best song lt my guess song never heard nothing heard could possibly candidate
# [CLS] already happens abs rower tweeting support nats last year deluge celeb endorsement obama
# [CLS] ciostrategyau as applicable business warfare battle future decided data ciqskwgdjj
# [CLS] euro ensembles much optimistic weekend even though operational counterpart deluge
# [CLS] havin previous life flashback lived weimar berlin hustlin life unter der linden deluge
# [CLS] bigdata deluge
# [CLS] decade long billion dollar deluge message government canada harperslegacy
# [CLS] do feel deluged unhappiness take quiz
# [CLS] why deluged low self image take quiz
# [CLS] thousand displaced house amp road deluged floodwater week persistent rain flood climate cdnpoli
# [CLS] businesses deluged invoice make stand colour shape anq likely rise top pay pile
# [CLS] businesses deluged invoice make stand colour shape likkly rise top o pay pile
# [CLS] police still searching two people rain mud deluged western town deutsche sprache
# [CLS] businesses cre deluged invoice make stand colour shape likely rise top pay cile
# [CLS] watching deluged data doczone ipad cbc
# [CLS] businesses deluged invoice make stand colour shape likely rise top che pay pile
# [CLS] businesses deluged invoice make stand colour shape likely rise top pay pipe
# [CLS] do feel deluged unhappiness take quiz
# [CLS] businesses deluged invoice make standwout colour shape likely rise top pay pile
# [CLS] businesses deluged invoicesx make stand ou colour shape likely rise top pay pile
# [CLS] my brain deluged thought
# [CLS] businesses deluged invoice make stand olour share likely rise top pay pile
# [CLS] businesses deluged invoicew make stand colouj shape likely rise top pay pile
# [CLS] businesses deluged invoice make stand colour shape ikely rise pay pile
# [CLS] believe never occurred could deluged kickstarter email
# [CLS] businesses deluged ivoices make stand colour shape likely ri top pay pile
# [CLS] is facebook deluged friending spam last day someone targeting reason
# [CLS] glimpses lt gt hyderabad lt gt deluged heavy rainfall hyderabad with flood water
# [CLS] deluged dismay soon surrendered summer drought descending disturbed sunrise haiku poetry wimberley atx smtx
# [CLS] the horror community deluged cruddy ostensibly macabre photography don contribute pandemic
# [CLS] barton le clay house owner told demolish extension bbc news inxvexrsyv
# [CLS] rt abbswinston zionist terrorist demolish tire repair shop structure bethlehem
# [CLS] salvation army bid demolish cottage southend enqascgfyw
# [CLS] enugu government demolish illegal structure international conference centre
# [CLS] contractor hired demolish goodrich plant miami file bankruptcy tulsa world manufacturing
# [CLS] enugu government demolish illegal structure international conference centre enugu state government app
# [CLS] demolish head corrupt vandalise head aliyu mani secschoolinnigeria
# [CLS] listen anakasparian demolish case planned parenthood whiny voice really love abortions defundpp
# [CLS] hope someone buy former post office napa sale preservation
# [CLS] we demolish team right eat pizza we need fitness ashton irwin mtvhottest
# [CLS] trying get higher bathroom work pen go demolish food
# [CLS] year old ring fort demolished
# [CLS] enugu government demolish illegal structure international conference centre rt
# [CLS] economic wisdom great economists demolish establishment nonsense the case logic reason
# [CLS] no shane sorry wrong you propagating attack would demolish england reversal
# [CLS] promise winningwhit could assemble team demolish

# %%
results = batch_predict(model, test_dataset)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
preds  = np.array(results[0])
target = np.array(results[1])

preds = np.where(preds > 0.47, 1, 0)

# %%
submissions = pd.read_csv('sample_submission.csv', index_col = 'id')
submissions
# Out:
#        target
# id
# 0           0
# 2           0
# 3           0
# 9           0
# 11          0
# ...       ...
# 10861       0
# 10865       0
# 10868       0
# 10874       0
# 10875       0
#
# [3263 rows x 1 columns]

# %%
submissions.loc[:, 'target'] = preds
submissions
# Out:
#        target
# id
# 0           1
# 2           1
# 3           1
# 9           1
# 11          1
# ...       ...
# 10861       1
# 10865       1
# 10868       1
# 10874       1
# 10875       1
#
# [3263 rows x 1 columns]

# %%
submissions.to_csv('my_submission.csv')
